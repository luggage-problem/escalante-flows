# %%
from datetime import datetime
import matplotlib
import flows_n_snows.utils as utils

# %%
# Out:
# <AxesSubplot:xlabel='datetime'>

# %%
# Out:
# processing data from request: https://waterservices.usgs.gov/nwis/dv/?format=waterml&site=09337500&startDT=1980-01-01&endDT=2022-01-17

# %%
flow_df['value'] = flow_df['value'].astype(float)

# %%
# Out:
# <AxesSubplot:xlabel='datetime'>
